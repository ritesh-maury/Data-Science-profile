# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

matches = pd.read_csv('matches.csv')
matches["type"] = "pre-qualifier"
matches.head()
for year in range(2008, 2017):
   final_match_index = matches[matches['season']==year][-1:].index.values[0]
   matches = matches.at[final_match_index, "type"]="final"
   #matches = matches.at[final_match_index-1, "type"]= "qualifier-2"
   #matches = matches.at[final_match_index-2, "type"]= "eliminator"
   #matches = matches.at[final_match_index-3, "type"]= "qualifier-1"

matches.groupby(["type"])["id"].count()
matches.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7e09c22131fe> in <module>
#      11 for year in range(2008, 2017):
#      12    final_match_index = matches[matches['season']==year][-1:].index.values[0]
# ---> 13    matches = matches.at[final_match_index, "type"]="final"
#      14    #matches = matches.at[final_match_index-1, "type"]= "qualifier-2"
#      15    #matches = matches.at[final_match_index-2, "type"]= "eliminator"
#
# AttributeError: 'str' object has no attribute 'at'

# %%
type(matches)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd 
  
# Creating the dataframe  
df = pd.DataFrame({"A":[1, 5, 3, 4, 2], 
                   "B":[3, 2, 4, 3, 4],  
                   "C":[2, 2, 7, 3, 4], 
                   "D":[4, 3, 6, 12, 7]}) 
  
# Print the dataframe 
df
# Out:
#    A  B  C   D
# 0  1  3  2   4
# 1  5  2  2   3
# 2  3  4  7   6
# 3  4  3  3  12
# 4  2  4  4   7

# %%
# set value of a cell which has index label "2" and column label "B" 
#df.set_value(2, 'B', 100)
df.at[2,"B"]=100
df
# Out:
#    A    B  C   D
# 0  1    3  2   4
# 1  5    2  2   3
# 2  3  100  7   6
# 3  4    3  3  12
# 4  2    4  4   7

# %%
ipl_data = pd.read_csv(r"F:\Nettech India\Aritficial Intelligence\Case study\IPL\matches.csv")
matches = pd.read_csv(r"F:\Nettech India\Aritficial Intelligence\Case study\IPL\matches.csv")

# %%
matches[matches.city=="Chennai"]
# Out:
#       id  season     city        date                        team1  \
# 66    67    2008  Chennai  23-04-2008          Chennai Super Kings
# 70    71    2008  Chennai  26-04-2008        Kolkata Knight Riders
# 78    79    2008  Chennai  02-05-2008          Chennai Super Kings
# 84    85    2008  Chennai  06-05-2008          Chennai Super Kings
# 90    91    2008  Chennai  10-05-2008          Chennai Super Kings
# 106  107    2008  Chennai  21-05-2008  Royal Challengers Bangalore
# 109  110    2008  Chennai  24-05-2008             Rajasthan Royals
# 178  179    2010  Chennai  14-03-2010              Deccan Chargers
# 189  190    2010  Chennai  21-03-2010              Kings XI Punjab
# 201  202    2010  Chennai  31-03-2010  Royal Challengers Bangalore
# 205  206    2010  Chennai  03-04-2010          Chennai Super Kings
# 210  211    2010  Chennai  06-04-2010          Chennai Super Kings
# 221  222    2010  Chennai  13-04-2010        Kolkata Knight Riders
# ...

# %%
wins_percity = matches[matches['season'] == 2008].groupby(['winner', 'city'])['id'].count().unstack()
plot = wins_percity.plot(kind='bar', stacked=True, title="Team wins in different cities\nSeason "+str(2008), figsize=(7, 5))
sns.set_palette("Paired", len(matches['city'].unique()))
plot.set_xlabel("Teams")
plot.set_ylabel("No of wins")
plot.legend(loc='best', prop={'size':8})
plt.show()

# %%
plt.plot(kind="pie")

# %%
x =2008
while x<=2016:
    wins_percity = matches[matches['season'] == x].groupby(['winner', 'city'])['id'].count().unstack()
    plot = wins_percity.plot(kind='bar', stacked=True, title="Team wins in different cities\nSeason "+str(x), figsize=(7, 5))
    sns.set_palette("Paired", len(matches['city'].unique()))
    plot.set_xlabel("Teams")
    plot.set_ylabel("No of wins")
    plot.legend(loc='best', prop={'size':8})
    plt.show()
    x = x+1

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl_data["type"] = "pre-qualifier"
for year in range(2008, 2017):
   final_match_index = ipl_data[ipl_data['season']==year][-1:].index.values[0]
   ipl_data = ipl_data.set_value(final_match_index, "type", "final")
   ipl_data = ipl_data.set_value(final_match_index-1, "type", "qualifier-2")
   ipl_data = ipl_data.set_value(final_match_index-2, "type", "eliminator")
   ipl_data = ipl_data.set_value(final_match_index-3, "type", "qualifier-1")
ipl_data.groupby(["type"])["id"].count()
#ipl_data.head()
# Out:
# type
# eliminator         9
# final              9
# pre-qualifier    600
# qualifier-1        9
# qualifier-2        9
# Name: id, dtype: int64

# %%
deliveries = pd.read_csv(r'F:\Nettech India\Aritficial Intelligence\Case study\IPL\deliveries.csv')
deliveries.head()
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
deliveries['inning'].value_counts()
# Out:
# 1    78029
# 2    72350
# 3       43
# 4       38
# Name: inning, dtype: int64

# %%
deliveries.groupby(['match_id', 'inning'])['total_runs'].sum().unstack().reset_index()
# Out:
# inning  match_id      1      2   3   4
# 0              1  207.0  172.0 NaN NaN
# 1              2  184.0  187.0 NaN NaN
# 2              3  183.0  184.0 NaN NaN
# 3              4  163.0  164.0 NaN NaN
# 4              5  157.0  142.0 NaN NaN
# ..           ...    ...    ...  ..  ..
# 631          632  138.0  139.0 NaN NaN
# 632          633  158.0  159.0 NaN NaN
# 633          634  162.0  140.0 NaN NaN
# 634          635  162.0  163.0 NaN NaN
# 635          636  208.0  200.0 NaN NaN
#
# [636 rows x 5 columns]

# %%
batsman_grp = deliveries.groupby(["match_id", "inning", "batting_team", "batsman"])
batsmen = batsman_grp["batsman_runs"].sum().reset_index()

# %%
balls_faced=deliveries[deliveries["wide_runs"] == 0]
balls_faced = balls_faced.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()
balls_faced.columns = ["match_id", "inning", "batsman", "balls_faced"]
balls_faced
# Out:
# match_id  inning  batsman
# 1         1       BCJ Cutting      6
#                   DA Warner        8
#                   DJ Hooda        12
#                   MC Henriques    37
#                   S Dhawan        31
#                                   ..
# 636       2       KL Rahul         9
#                   SR Watson        9
#                   STR Binny        7
#                   Sachin Baby     10
#                   V Kohli         35
# Name: batsman_runs, Length: 9546, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor
data = matches[['team1', 'team2', 'venue', 'toss_winner','city','toss_decision','winner']]

# %%
#matches['winner'].fillna('Draw', inplace=True)
data[pd.isnull(data['winner'])]
data[data.city=="Chennai"]
# Out:
#                            team1                        team2  \
# 66           Chennai Super Kings               Mumbai Indians
# 70         Kolkata Knight Riders          Chennai Super Kings
# 78           Chennai Super Kings             Delhi Daredevils
# 84           Chennai Super Kings              Deccan Chargers
# 90           Chennai Super Kings              Kings XI Punjab
# 106  Royal Challengers Bangalore          Chennai Super Kings
# 109             Rajasthan Royals          Chennai Super Kings
# 178              Deccan Chargers          Chennai Super Kings
# 189              Kings XI Punjab          Chennai Super Kings
# 201  Royal Challengers Bangalore          Chennai Super Kings
# 205          Chennai Super Kings             Rajasthan Royals
# 210          Chennai Super Kings               Mumbai Indians
# 221        Kolkata Knight Riders          Chennai Super Kings
# 223          Chennai Super Kings             Delhi Daredevils
# ...

# %%
data.replace(['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore','Deccan Chargers','Chennai Super Kings',
                 'Rajasthan Royals','Delhi Daredevils','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants','Rising Pune Supergiant','Kochi Tuskers Kerala','Pune Warriors']
                ,['MI','KKR','RCB','DC','CSK','RR','DD','GL','KXIP','SRH','RPS','RPS','KTK','PW'],inplace=True)

encode = {'team1': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'team2': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'toss_winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13},
          'winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'Draw':14}}
data.replace(encode, inplace=True)
# Out:
# C:\Users\Ritesh Maurya\Anaconda3\lib\site-packages\pandas\core\frame.py:4263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# C:\Users\Ritesh Maurya\Anaconda3\lib\site-packages\pandas\core\generic.py:6702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regex=regex,

# %%
data['city'].fillna('Dubai',inplace=True)
data[pd.isnull(data['city'])]
d
# Out:
# C:\Users\Ritesh Maurya\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-179-5bed5f7c2e4d> in <module>
#       1 data['city'].fillna('Dubai',inplace=True)
#       2 data[pd.isnull(data['city'])]
# ----> 3 d
#
# NameError: name 'd' is not defined

# %%
data.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# team1            0
# team2            0
# venue            0
# toss_winner      0
# city             0
# toss_decision    0
# winner           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le1= LabelEncoder()
le2= LabelEncoder()
le3= LabelEncoder()
le4 = LabelEncoder()
data['city'] = le1.fit_transform(data['city'])
data['venue'] = le1.fit_transform(data['venue'])
data['toss_decision'] = le1.fit_transform(data['toss_decision'])
data.head(71)
# Out:
# C:\Users\Ritesh Maurya\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Ritesh Maurya\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Ritesh Maurya\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
X = data.iloc[:,0:6]
y = data.iloc[:,6]
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)
X_train
# Out:
#      team1  team2  venue  toss_winner  city  toss_decision
# 426      6      2      7            6    21              0
# 392      6     13     31            6    25              0
# 602     10      3     23            3    14              1
# 310      6      9     26            9    16              1
# 500      1      6     24            1     1              0
# ..     ...    ...    ...          ...   ...            ...
# 9       10      1     34            1    22              1
# 359      1      3     34            3    22              1
# 192      6      9     22            9     6              1
# 629      1      8      9            8    18              1
# 559      9      2      7            9    21              0
#
# [540 rows x 6 columns]

# %%
# Fitting Random Forest Classification to the Training set
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred = model.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
accuracy_score(y_test,y_pred)
# Out:
# 0.5208333333333334

# %% [markdown]
# # Prediction on New data

# %%
Team1 = 1
Team2 = 5
venue = 14
toss_winner = 5
city = 7#"Chennai"
toss_decision = 0
import numpy as np

# %%
new = np.array([Team1,Team2,venue,toss_winner,city,toss_decision])
new = new.reshape(1,-1)
new=pd.DataFrame(new)
new.shape
new
# Out:
#    0  1   2  3  4  5
# 0  1  5  14  5  7  0

# %%
model.predict(new)
# Out:
# array([5], dtype=int64)

# %% [markdown]
# # Visualization of model (With LDA)

# %%
# Applying LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components = 2,solver='eigen',shrinkage="auto")
X_train_lda = lda.fit_transform(X_train,y_train)
X_test_lda = lda.transform(X_test)
model1 = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
model1.fit(X_train_lda, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
X_train_lda.shape
# Out:
# (540, 2)

# %%
y_train.value_counts()
# Out:
# 1     77
# 2     70
# 9     68
# 5     64
# 3     59
# 6     52
# 7     49
# 10    36
# 4     24
# 11    12
# 8     12
# 13    10
# 12     5
# 14     2
# Name: winner, dtype: int64

# %%
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green', 'blue','black','yellow','orange','pink','#9C20B7','#A664B4','#7DB464','#E7E751','#E351E7','#968497','#5343B0'))(i), label = j)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
