# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\Edubridge\Batch-2\Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Fare"].sum()
# Out:
# 28693.9493

# %%
a = df[["Fare","Age"]].cumsum()

# %%
a.plot()
plt.title("Trend of Age and Fare")
plt.xlabel("No of Rows")
plt.ylabel("Values")
plt.show()

# %%
df["Survived"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#Frequency of Ages
df["Age"].value_counts().sort_values().plot(kind="barh",figsize=(10,20))
plt.show()

# %%
df["Age"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(df["Age"],bins=[0,15,30,45,60,75,85],alpha=1,color="red")
plt.xticks([0,15,30,45,60,75,85])
plt.show()

# %% [markdown]
# # Basic Bar plot

# %%
language = ["C++","R","Python","SaS","Julia"]
students = [10,56,23,7,89]
plt.bar(language,students,color=["red","blue","green","orange","yellow"])
plt.show()

# %% [markdown]
# # Basic Histograrm

# %%
#From titanic dataset
plt.hist(df["Age"],bins=[0,15,30,45,60,75,85],alpha=1,color="red")
plt.xticks([0,15,30,45,60,75,85])
plt.show()

# %%
g = df.groupby(["Survived","Sex"])

# %%
g.size().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Survived,Sex'>

# %% [markdown]
# # Boxplot

# %%
import seaborn as sns

# %%
sns.boxplot(data=df,x="Survived",y="Age")
sns.stripplot(data=df,x="Survived",y="Age")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(data=df,x="Survived",y="Fare")
sns.stripplot(data=df,x="Survived",y="Fare")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.violinplot(data=df,x="Survived",y="Age")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.violinplot(data=df,x="Survived",y="Fare")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %% [markdown]
# # Seaborn: Visualization

# %%
sns.distplot(df["Age"],kde=False)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["Age"],kde=True)
plt.show()

# %%
#Scatter plot
sns.jointplot(x="Age",y="Fare",data=df)

# %%
sns.jointplot(x="Age",y="Fare",data=df,kind="hex")

# %%
#Stripplot
sns.boxplot(data=df,x="Survived",y="Fare")
sns.stripplot(data=df,x="Survived",y="Fare")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %% [markdown]
# # Bar plot

# %% [markdown]
# # Visualization of Titanic dataset

# %%
#find no of survived and non survived passenger
sns.countplot("Survived",data=df)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# # Subplotting

# %%
fig, axs = plt.subplots(2,2,figsize=(13,15))

df["Sex"].value_counts().plot(kind="bar",color=["red","green"],ax=axs[0][1])
axs[0][1].set_title("Number of Passengers with Sex columns")
axs[0][1].grid(True)

sns.countplot("Sex",hue="Survived",data=df,ax=axs[0][0])
axs[0][0].set_title("Survived with Gender columns")
axs[0][0].grid(True)

axs[1][0].scatter(df["Age"],df["Fare"])
axs[1][0].set_title("Scatter plotting between Age & Fare")

sns.boxplot(x="Survived",y="Age",data=df,ax=axs[1][1])
axs[1][1].set_title("Boxplot with Survived and Age columns")

plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df["Sex"].value_counts().plot(kind="bar",color=["red","green"])
# Out:
# <AxesSubplot:>

# %%
sns.countplot("Sex",hue="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.factorplot(x = "Pclass",y = "Survived", hue="Sex", data=df)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
f = pd.crosstab([df["Sex"],df["Survived"]],df["Pclass"], margins=True)
f.style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
# #T_97c97_row0_col0,#T_97c97_row0_col1,#T_97c97_row0_col3,#T_97c97_row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_97c97_row0_col2,#T_97c97_row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_97c97_row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_97c97_row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_97c97_row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_97c97_row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_97c97_row2_col1,#T_97c97_row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_97c97_row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_97c97_row3_col0{
# ...

# %%
sns.countplot(x="Sex",hue="Pclass",data=df)
plt.grid(True)

# %%
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=df)
plt.grid(True)

# %%
#Average age of diffrent classes
df.groupby("Pclass")["Age"].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
h = pd.crosstab([df["Embarked"],df["Survived"]], df["Sex"], margins=True)
h.style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
# #T_c236a_row0_col0,#T_c236a_row2_col0,#T_c236a_row3_col1,#T_c236a_row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_c236a_row0_col1{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_c236a_row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_c236a_row1_col0{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_c236a_row1_col1{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_c236a_row1_col2{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_c236a_row2_col1,#T_c236a_row3_col0{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_c236a_row2_col2{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_c236a_row4_col0{
#             background-color:  #d2e866;
# ...

# %%
h = pd.crosstab([df["Embarked"],df["Survived"]], df["Pclass"], margins=True)
h.style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
# #T_b8ddb_row0_col0{
#             background-color:  #e1f066;
#             color:  #000000;
#         }#T_b8ddb_row0_col1{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_b8ddb_row0_col2{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_b8ddb_row0_col3{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_b8ddb_row1_col0{
#             background-color:  #badc66;
#             color:  #000000;
#         }#T_b8ddb_row1_col1{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_b8ddb_row1_col2,#T_b8ddb_row2_col0,#T_b8ddb_row2_col1,#T_b8ddb_row3_col0,#T_b8ddb_row3_col3{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_b8ddb_row1_col3{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_b8ddb_row2_col2{
#             background-color:  #f5fa66;
# ...

# %%
h = pd.crosstab([df["Sex"],df["Survived"]], df["SibSp"], margins=True)
h.style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
# #T_1e34b_row0_col0,#T_1e34b_row0_col1,#T_1e34b_row0_col2,#T_1e34b_row0_col7,#T_1e34b_row1_col5,#T_1e34b_row1_col6,#T_1e34b_row3_col2,#T_1e34b_row3_col3,#T_1e34b_row3_col4,#T_1e34b_row3_col5,#T_1e34b_row3_col6{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1e34b_row0_col3{
#             background-color:  #8fc766;
#             color:  #000000;
#         }#T_1e34b_row0_col4{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_1e34b_row0_col5{
#             background-color:  #cce666;
#             color:  #000000;
#         }#T_1e34b_row0_col6{
#             background-color:  #92c866;
#             color:  #000000;
#         }#T_1e34b_row1_col0{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_1e34b_row1_col1{
#             background-color:  #b4da66;
#             color:  #000000;
#         }#T_1e34b_row1_col2{
# ...

# %%
sns.boxplot(x="Survived",y='Age',data=df)
plt.show()

# %%
sns.swarmplot(x="Survived",y='Age',data=df)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
cr = df.corr()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(cr,annot=True,cmap="gnuplot2_r")
plt.show()
